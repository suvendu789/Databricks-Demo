# %%
print("Hello world")

# %%
# %sql
SELECT "Hello world from SQL!"

# %% [markdown]
# # Title 1
# ## Title 2
# ### Title 3

# %%
# %run ./Includes/Setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls("/databricks-datasets/")
print(files)

# %%
display(files)
